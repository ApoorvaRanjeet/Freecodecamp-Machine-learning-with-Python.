# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
housing_dataset=pd.read_csv('/content/Housing.csv')

# %%
housing_dataset.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
housing_dataset.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
housing_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
housing_dataset.shape
# Out:
# (545, 13)

# %%
housing_dataset.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
housing_dataset.boxplot()
# Out:
# <Axes: >

# %%
# Independent features and dependent features


housing_dataset = pd.get_dummies(housing_dataset, columns=['guestroom','basement','hotwaterheating','airconditioning','prefarea'], drop_first=True)
housing_dataset = pd.get_dummies(housing_dataset, columns=['mainroad'], drop_first=True)
housing_dataset = pd.get_dummies(housing_dataset, columns=['furnishingstatus'], drop_first=True)

X = housing_dataset.drop(columns='price',axis=1)
Y = housing_dataset['price']

# %%
housing_dataset
# Out:
#         price  area  bedrooms  bathrooms  stories  parking  guestroom_yes  \
# 0    13300000  7420         4          2        3        2              0
# 1    12250000  8960         4          4        4        3              0
# 2    12250000  9960         3          2        2        2              0
# 3    12215000  7500         4          2        2        3              0
# 4    11410000  7420         4          1        2        2              1
# ..        ...   ...       ...        ...      ...      ...            ...
# 540   1820000  3000         2          1        1        2              0
# 541   1767150  2400         3          1        1        0              0
# 542   1750000  3620         2          1        1        0              0
# 543   1750000  2910         3          1        1        0              0
# 544   1750000  3850         3          1        2        0              0
#
#      basement_yes  hotwaterheating_yes  airconditioning_yes  prefarea_yes  \
# 0               0                    0                    1             1
# 1               0                    0                    1             0
# 2               1                    0                    0             1
# 3               1                    0                    1             1
# 4               1                    0                    1             0
# ..            ...                  ...                  ...           ...
# 540             1                    0                    0             0
# 541             0                    0                    0             0
# 542             0                    0                    0             0
# 543             0                    0                    0             0
# 544             0                    0                    0             0
#
#      mainroad_yes  furnishingstatus_semi-furnished  \
# 0               1                                0
# 1               1                                0
# 2               1                                1
# 3               1                                0
# 4               1                                0
# ..            ...                              ...
# 540             1                                0
# 541             0                                1
# 542             1                                0
# 543             0                                0
# 544             1                                0
#
#      furnishingstatus_unfurnished
# 0                               0
# 1                               0
# 2                               0
# 3                               0
# 4                               0
# ..                            ...
# 540                             1
# 541                             0
# 542                             1
# 543                             0
# 544                             1
#
# [545 rows x 14 columns]

# %%
print(Y)
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
print(X)
# Out:
#      area  bedrooms  bathrooms  stories  parking  guestroom_yes  basement_yes  \
# 0    7420         4          2        3        2              0             0
# 1    8960         4          4        4        3              0             0
# 2    9960         3          2        2        2              0             1
# 3    7500         4          2        2        3              0             1
# 4    7420         4          1        2        2              1             1
# ..    ...       ...        ...      ...      ...            ...           ...
# 540  3000         2          1        1        2              0             1
# 541  2400         3          1        1        0              0             0
# 542  3620         2          1        1        0              0             0
# 543  2910         3          1        1        0              0             0
# 544  3850         3          1        2        0              0             0
#
#      hotwaterheating_yes  airconditioning_yes  prefarea_yes  mainroad_yes  \
# 0                      0                    1             1             1
# 1                      0                    1             0             1
# 2                      0                    0             1             1
# 3                      0                    1             1             1
# 4                      0                    1             0             1
# ..                   ...                  ...           ...           ...
# 540                    0                    0             0             1
# 541                    0                    0             0             0
# 542                    0                    0             0             1
# 543                    0                    0             0             0
# 544                    0                    0             0             1
#
#      furnishingstatus_semi-furnished  furnishingstatus_unfurnished
# 0                                  0                             0
# 1                                  0                             0
# 2                                  1                             0
# 3                                  0                             0
# 4                                  0                             0
# ..                               ...                           ...
# 540                                0                             1
# 541                                1                             0
# 542                                0                             1
# 543                                0                             0
# 544                                0                             1
#
# [545 rows x 13 columns]

# %%
# train test spit
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=.30,random_state=42)

# %%
X_train
# Out:
#      area  bedrooms  bathrooms  stories  parking  guestroom_yes  basement_yes  \
# 126  7160         3          1        1        2              0             1
# 363  3584         2          1        1        0              0             0
# 370  4280         2          1        1        2              0             0
# 31   7000         3          1        4        2              0             0
# 113  9620         3          1        1        2              0             1
# ..    ...       ...        ...      ...      ...            ...           ...
# 71   6000         4          2        4        0              0             0
# 106  5450         4          2        1        0              0             1
# 270  4500         3          2        3        1              0             0
# 435  4040         2          1        1        0              0             0
# 102  5500         3          2        4        1              1             0
#
#      hotwaterheating_yes  airconditioning_yes  prefarea_yes  mainroad_yes  \
# 126                    0                    0             1             1
# 363                    1                    0             0             1
# 370                    0                    1             0             1
# 31                     0                    1             0             1
# 113                    0                    0             1             1
# ..                   ...                  ...           ...           ...
# 71                     0                    1             0             1
# 106                    0                    1             1             1
# 270                    1                    0             0             1
# 435                    0                    0             0             1
# 102                    0                    1             0             1
#
#      furnishingstatus_semi-furnished  furnishingstatus_unfurnished
# 126                                0                             1
# 363                                1                             0
# 370                                1                             0
# 31                                 1                             0
# 113                                0                             0
# ..                               ...                           ...
# 71                                 0                             1
# 106                                1                             0
# 270                                0                             0
# 435                                0                             1
# 102                                1                             0
#
# [381 rows x 13 columns]

# %%
X_test
# Out:
#      area  bedrooms  bathrooms  stories  parking  guestroom_yes  basement_yes  \
# 316  5900         4          2        2        1              0             1
# 77   6500         3          2        3        0              0             0
# 360  4040         2          1        1        0              0             0
# 90   5000         3          1        2        0              0             0
# 493  3960         3          1        1        0              0             0
# ..    ...       ...        ...      ...      ...            ...           ...
# 395  3600         6          1        2        1              0             0
# 425  3185         2          1        1        2              0             1
# 195  4410         4          3        2        2              0             1
# 452  9000         3          1        2        2              0             0
# 154  3650         3          2        2        2              0             0
#
#      hotwaterheating_yes  airconditioning_yes  prefarea_yes  mainroad_yes  \
# 316                    0                    0             0             0
# 77                     0                    1             1             1
# 360                    0                    0             0             1
# 90                     0                    1             0             1
# 493                    0                    0             0             1
# ..                   ...                  ...           ...           ...
# 395                    0                    0             0             1
# 425                    0                    0             0             1
# 195                    0                    0             0             1
# 452                    0                    0             0             1
# 154                    0                    0             0             1
#
#      furnishingstatus_semi-furnished  furnishingstatus_unfurnished
# 316                                0                             1
# 77                                 0                             0
# 360                                1                             0
# 90                                 1                             0
# 493                                0                             0
# ..                               ...                           ...
# 395                                0                             1
# 425                                0                             0
# 195                                1                             0
# 452                                1                             0
# 154                                1                             0
#
# [164 rows x 13 columns]

# %%
Y_train
# Out:
# 126    5880000
# 363    3710000
# 370    3640000
# 31     8400000
# 113    6083000
#         ...
# 71     6755000
# 106    6160000
# 270    4340000
# 435    3290000
# 102    6195000
# Name: price, Length: 381, dtype: int64

# %%
Y_test
# Out:
# 316    4060000
# 77     6650000
# 360    3710000
# 90     6440000
# 493    2800000
#         ...
# 395    3500000
# 425    3360000
# 195    4970000
# 452    3150000
# 154    5530000
# Name: price, Length: 164, dtype: int64

# %%
# standerdizing the dataset  (it is important to standardize the dataset to get better output)

from sklearn.preprocessing import StandardScaler

# we will initialize the standard scaler.

scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# cross validation
from sklearn.model_selection import cross_val_score

# %%
regression = LinearRegression()
regression.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
mse = cross_val_score(regression,X_train,Y_train,scoring='neg_mean_squared_error',cv=5)

# %%
np.mean(mse)
# Out:
# -1103290784307.4917

# %%
# prediction

reg_predict=regression.predict(X_test)

# %%
reg_predict
# Out:
# array([5372312.61614641, 7069241.00525806, 3099290.78784024,
#        4526446.61703974, 3281573.61192656, 3589455.18752547,
#        5728625.30074515, 6422877.52476237, 2797870.49568591,
#        2554357.99210552, 9693560.19894656, 2802903.76131031,
#        3026465.95300837, 3433891.33202093, 3792786.34565513,
#        5321204.36478555, 2999852.37322994, 4813306.52790376,
#        4572077.61633938, 3595733.80237382, 5605701.03333099,
#        5838934.41614981, 2730716.89440109, 4837741.37096247,
#        5638460.49223856, 7809681.30410654, 3347443.37529207,
#        5328750.6625753 , 8323072.83237386, 3374792.28854335,
#        6379706.15324899, 3397999.89564252, 6709115.82334019,
#        4249666.18392567, 3594972.20315591, 5842994.13027721,
#        5115480.11172668, 4359421.90319848, 3046570.15372424,
#        4597379.56416965, 4784358.17589609, 3411743.7822068 ,
#        7048978.02507302, 4062741.36892573, 3785699.2416086 ,
#        4286017.77250844, 6729020.2073964 , 4133428.23821411,
#        3845434.09183082, 3655159.46220358, 7439302.79944483,
#        2869444.70398564, 4468816.13830399, 4474332.83085885,
#        3790094.69366283, 2607548.31509126, 7484173.67473394,
#        2912521.83764141, 4288766.92856502, 2768963.26950036,
#        5085040.92323165, 3552078.21169882, 5302353.24799836,
#        4231219.34966538, 4777666.66597256, 4749128.97396195,
#        7227708.34560926, 3547097.71091148, 6257007.3620145 ,
#        6281861.39296942, 4724974.20779798, 5111537.60350725,
#        4628387.10726121, 8033569.61251156, 3475245.27785437,
#        5465194.44654502, 4099826.20844264, 4490619.8427956 ,
#        4787230.18858055, 4016745.04174708, 7720896.40387667,
#        4213805.47198352, 6660115.77473413, 5403121.59582178,
#        2735220.76102228, 7105152.1027995 , 2596569.15845831,
#        3751123.26669058, 7989380.8913285 , 8385201.9710021 ,
#        3292999.34804884, 6064783.11075628, 3578078.476602  ,
#        3715646.2039554 , 7866539.40858855, 4675429.52635589,
#        5241467.95089469, 6408824.17914904, 4927283.22506899,
#        6016039.22482594, 4001044.18004055, 6543468.56266503,
#        3743701.72935292, 6122124.82004408, 5263613.65957781,
#        4427035.02710476, 7113024.58500312, 6473306.81656723,
#        6536377.59307021, 7153784.10673248, 7173099.40073648,
#        4938872.4464758 , 3957507.77132248, 3254459.62826403,
#        4325743.66584545, 3279788.35349534, 2764977.26281621,
#        2284744.63243067, 3681692.68869108, 4055332.4997858 ,
#        3756783.55352125, 4960900.56796538, 3961010.02251466,
#        4060631.63414301, 6010508.2848805 , 2356719.15341124,
#        5620463.04275165, 3359695.73124725, 8069125.43392246,
#        6899820.48632772, 3334032.76681399, 4994371.64761067,
#        6991813.31353786, 6600920.56859718, 3229130.90303273,
#        2319097.19096211, 3170052.43901872, 5647944.6452336 ,
#        3096476.70963452, 3974934.22682987, 2615575.52371791,
#        3976282.03954355, 5277503.71800008, 4077504.49355871,
#        4161209.69078219, 2393816.93039446, 6813169.01830005,
#        5341221.01242614, 6847577.16463817, 7279768.48835276,
#        5512369.54760752, 4572538.51080985, 3812830.38534952,
#        3834646.21553009, 3350648.20235337, 7315891.3952515 ,
#        8107534.58411868, 3976263.27565868, 7187281.98339335,
#        3762257.2005658 , 4093208.84466661, 7090389.284054  ,
#        5459978.75336372, 5219643.13131587])

# %%
import seaborn as sns

sns.displot(reg_predict-Y_test,kind='kde')

# %%
from sklearn.metrics import r2_score

# %%
score=r2_score(reg_predict,Y_test)

# %%
score
# Out:
# 0.40531970710343157
